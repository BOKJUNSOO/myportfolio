# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\brian\Desktop\JUNSOO\exhibition\data\SchoolCircle.csv" , encoding='cp949')

# %%
df.info()
df['지역'] = (df['지역']
                        .fillna('서울특별시 기타'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4609 entries, 0 to 4608
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   시도교육청                    4609 non-null   object
#  1   시도교육청코드                  4609 non-null   object
#  2   교육지원청                    4609 non-null   object
#  3   교육지원청코드                  4609 non-null   object
#  4   지역                       4608 non-null   object
#  5   지역코드                     4608 non-null   float64
#  6   소재지구분코드                  4609 non-null   int64
#  7   정보공시 학교코드                4609 non-null   object
#  8   학교명                      4609 non-null   object
#  9   학교급코드                    4609 non-null   int64
#  10  설립구분                     4609 non-null   object
#  11  제외여부                     4609 non-null   object
#  12  제외사유                     13 non-null     object
#  13  창의적체험활동동아리 동아리수          4596 non-null   float64
# ...

# %%
df_creative_circle = df[['지역' ,'창의적체험활동동아리 동아리수'
                        , '창의적체험활동동아리 동아리활동 예산지원현황'
                        , '공시연도']]
# 동아리활동 예산지원 현황 데이터프레임
df_creative_circle_2021_m = df_creative_circle[df_creative_circle['공시연도'] == 2021][['지역', '창의적체험활동동아리 동아리활동 예산지원현황']]
df_creative_circle_2022_m = df_creative_circle[df_creative_circle['공시연도'] == 2022][['지역', '창의적체험활동동아리 동아리활동 예산지원현황']]
df_creative_circle_2023_m = df_creative_circle[df_creative_circle['공시연도'] == 2023][['지역', '창의적체험활동동아리 동아리활동 예산지원현황']]
df_creative_circle_2024_m = df_creative_circle[df_creative_circle['공시연도'] == 2024][['지역', '창의적체험활동동아리 동아리활동 예산지원현황']]


df_circle_free = df[['지역' 
                     , '학생자율동아리 동아리수'
                     , '학생자율동아리 동아리활동 예산지원현황'
                     , '공시연도']]

# 자율동아리 활동 예산지원 현황데이터프레임

df_circle_free_2021_m = df_circle_free[df_circle_free['공시연도'] == 2021][['지역', '학생자율동아리 동아리활동 예산지원현황']]
df_circle_free_2022_m = df_circle_free[df_circle_free['공시연도'] == 2022][['지역', '학생자율동아리 동아리활동 예산지원현황']]
df_circle_free_2023_m = df_circle_free[df_circle_free['공시연도'] == 2023][['지역', '학생자율동아리 동아리활동 예산지원현황']]
df_circle_free_2024_m = df_circle_free[df_circle_free['공시연도'] == 2024][['지역', '학생자율동아리 동아리활동 예산지원현황']]

# %%
print(df_creative_circle_2021_m['창의적체험활동동아리 동아리활동 예산지원현황'].sum()
      ,df_creative_circle_2022_m['창의적체험활동동아리 동아리활동 예산지원현황'].sum()
      ,df_creative_circle_2023_m['창의적체험활동동아리 동아리활동 예산지원현황'].sum()
      ,df_creative_circle_2024_m['창의적체험활동동아리 동아리활동 예산지원현황'].sum()
      ,sep = '\n')

print(df_circle_free_2021_m['학생자율동아리 동아리활동 예산지원현황'].sum()
      ,df_circle_free_2022_m['학생자율동아리 동아리활동 예산지원현황'].sum()
      ,df_circle_free_2023_m['학생자율동아리 동아리활동 예산지원현황'].sum()
      ,df_circle_free_2024_m['학생자율동아리 동아리활동 예산지원현황'].sum()
      ,sep = '\n')
# Out:
# 3163487408.0
# 8372058162.0
# 8420581550.0
# 8329634210.0
# 422781900.0
# 2300347763.0
# 2029173360.0
# 1715412771.0

# %%
#창의적체험활동동아리 동아리수

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'Malgun Gothic'

#창의적체험활동동아리 동아리수
df_creative_circle_var = (df_creative_circle
               .groupby(['지역'])['창의적체험활동동아리 동아리수']
               .sum())

df_creative_circle_var.plot(kind ='bar' , x = '지역', y = '창의적체험활동동아리 동아리수'
             , figsize = (10,6) , color = 'skyblue')

plt.title('창의적체험활동동아리 동아리수')
plt.xlabel('지역')
plt.ylabel('창의적체험활동동아리 동아리수')
# Out:
# Text(0, 0.5, '창의적체험활동동아리 동아리수')

# %%
#2021창의적체험활동동아리 동아리활동 예산지원현황

df_creative_circle_2021_m_p = (df_creative_circle_2021_m
                                .groupby(['지역'])['창의적체험활동동아리 동아리활동 예산지원현황']
                                .sum())

df_creative_circle_2021_m_p.plot(kind ='bar' , x = '지역', y = '창의적체험활동동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2021창의적체험활동동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2021창의적체험활동동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2021창의적체험활동동아리 동아리활동 예산지원현황')

# %%
#2022창의적체험활동동아리 동아리활동 예산지원현황

df_creative_circle_2022_m_p = (df_creative_circle_2022_m
                                .groupby(['지역'])['창의적체험활동동아리 동아리활동 예산지원현황']
                                .sum())

df_creative_circle_2022_m_p.plot(kind ='bar' , x = '지역', y = '창의적체험활동동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2022창의적체험활동동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2022창의적체험활동동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2022창의적체험활동동아리 동아리활동 예산지원현황')

# %%
#2023창의적체험활동동아리 동아리활동 예산지원현황

df_creative_circle_2023_m_p = (df_creative_circle_2023_m
                                .groupby(['지역'])['창의적체험활동동아리 동아리활동 예산지원현황']
                                .sum())

df_creative_circle_2023_m_p.plot(kind ='bar' , x = '지역', y = '창의적체험활동동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2023창의적체험활동동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2023창의적체험활동동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2023창의적체험활동동아리 동아리활동 예산지원현황')

# %%
#2021학생자율동아리 동아리활동 예산지원현황

df_creative_circle_2024_m_p = (df_creative_circle_2024_m
                                .groupby(['지역'])['학생자율동아리 동아리활동 예산지원현황']
                                .sum())

df_creative_circle_2024_m_p.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'pink')

plt.title('2021학생자율동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2024학생자율동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2024창의적체험활동동아리 동아리활동 예산지원현황')

# %%
#학생자율동아리 동아리수
df_circle_free_g = (df_circle_free
               .groupby(['지역'])['학생자율동아리 동아리수']
               .sum())

df_circle_free_g.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리수'
             , figsize = (10,6) , color = 'olive')

plt.title('학생자율동아리 동아리수')
plt.xlabel('지역')
plt.ylabel('학생자율동아리 동아리수')
# Out:
# Text(0, 0.5, '학생자율동아리 동아리수')

# %%
#2021학생자율동아리 동아리활동 예산지원현황

df_circle_free_2021_m_p = (df_circle_free_2021_m
                                .groupby(['지역'])['학생자율동아리 동아리활동 예산지원현황']
                                .sum())

df_circle_free_2021_m_p.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2021학생자율동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2021학생자율동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2021학생자율동아리 동아리활동 예산지원현황')

# %%
#2022학생자율동아리 동아리활동 예산지원현황

df_circle_free_2022_m_p = (df_circle_free_2022_m
                                .groupby(['지역'])['학생자율동아리 동아리활동 예산지원현황']
                                .sum())

df_circle_free_2022_m_p.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2022학생자율동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2022학생자율동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2022학생자율동아리 동아리활동 예산지원현황')

# %%
#2023학생자율동아리 동아리활동 예산지원현황

df_circle_free_2023_m_p = (df_circle_free_2023_m
                                .groupby(['지역'])['학생자율동아리 동아리활동 예산지원현황']
                                .sum())

df_circle_free_2023_m_p.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2023학생자율동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2023학생자율동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2023학생자율동아리 동아리활동 예산지원현황')

# %%
#2024학생자율동아리 동아리활동 예산지원현황

df_circle_free_2024_m_p = (df_circle_free_2024_m
                                .groupby(['지역'])['학생자율동아리 동아리활동 예산지원현황']
                                .sum())

df_circle_free_2024_m_p.plot(kind ='bar' , x = '지역', y = '학생자율동아리 동아리활동 예산지원현황'
                                    , figsize = (10,6) , color = 'gray')

plt.title('2024학생자율동아리 동아리활동 예산지원현황')
plt.xlabel('지역')
plt.ylabel('2024학생자율동아리 동아리활동 예산지원현황')
# Out:
# Text(0, 0.5, '2024학생자율동아리 동아리활동 예산지원현황')
