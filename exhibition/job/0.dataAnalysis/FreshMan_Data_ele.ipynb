# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\brian\Desktop\JUNSOO\exhibition\data\FreshMan.csv" , encoding='cp949')

# %%
## 초중고 의미있는 칼럼 추출

df_ele_col = ['지역'
               ,'적령 아동-합계', '유예 및 과령 아동-합계'
               ,'조기입학아동-합계'
               ]       #초등학교 데이터 열

df_MH_col = ['지역'
                 ,'당해연도 졸업자-합계'
                 ,'이전연도 졸업자-합계'
                 ,'검정고시 및 교육과정 이수자-합계'
                 ]      #중학교 고등학교는 데이터 열 동일

## 데이터 프레임 정의
df_ele_df = df[df_ele_col]
df_middle_df = df[df_MH_col]
df_high_df = df[df_MH_col]

# 2021 데이터
df_2021_ele = df_ele_df.iloc[0:603,:]
df_2021_middle = df_middle_df.iloc[603:992,:]
df_2021_high = df_high_df.iloc[992:1317,:]

# 2022 데이터
df_2022_ele = df_ele_df.iloc[1408:2010,:]
df_2022_middle = df_middle_df.iloc[2010:2405,:]
df_2022_high = df_high_df.iloc[2435:2763,:]

#2023 데이터
df_2023_ele1 = df_ele_df.iloc[2405:2435,:]
df_2023_ele2 = df_ele_df.iloc[2763:2780,:]
df_2023_ele3 = df_ele_df.iloc[2868:3418,:]      #2023초등학교 데이터가 순서대로 정렬되어 있지 않음
concat_2023_ele = pd.concat([df_2023_ele1,
                         df_2023_ele2,
                         df_2023_ele3])

df_2023_middle = df_middle_df.iloc[3418:3815,:]
df_2023_high = df_high_df.iloc[3841:4170,:]

#2024 데이터
df_2024_ele1 = df_ele_df.iloc[3815:3841,:]
df_2024_ele2 = df_ele_df.iloc[4170:4182,:]
df_2024_ele3 = df_ele_df.iloc[4272:4827,:]      #2024초등학교 데이터가 순서대로 정렬되어 있지 않음
concat_2024_ele = pd.concat([df_2024_ele1,
                         df_2024_ele2,
                         df_2024_ele3])


df_2024_middle = df_middle_df.iloc[4827:5215,:]
df_2024_high = df_high_df.iloc[5215:5538,:]

## 결측값 처리
#초등학교
concat_2024_ele['적령 아동-합계'] = concat_2024_ele['적령 아동-합계'].fillna(105)
concat_2024_ele['유예 및 과령 아동-합계'] = concat_2024_ele['유예 및 과령 아동-합계'].fillna(0)
concat_2024_ele['조기입학아동-합계'] = concat_2024_ele['조기입학아동-합계'].fillna(0)

#중학교
df_2022_middle['당해연도 졸업자-합계'] = df_2022_middle['당해연도 졸업자-합계'].fillna(207)
df_2022_middle['이전연도 졸업자-합계'] = df_2022_middle['이전연도 졸업자-합계'].fillna(1)
df_2022_middle['검정고시 및 교육과정 이수자-합계'] = df_2022_middle['검정고시 및 교육과정 이수자-합계'].fillna(2)

df_2023_high['당해연도 졸업자-합계'] = df_2023_high['당해연도 졸업자-합계'].fillna(207)
df_2023_high['이전연도 졸업자-합계'] = df_2023_high['이전연도 졸업자-합계'].fillna(1)
df_2023_high['검정고시 및 교육과정 이수자-합계'] = df_2023_high['검정고시 및 교육과정 이수자-합계'].fillna(2)



#고등학교
df_2022_high['당해연도 졸업자-합계'] = df_2022_high['당해연도 졸업자-합계'].fillna(207)
df_2022_high['이전연도 졸업자-합계'] = df_2022_high['이전연도 졸업자-합계'].fillna(1)
df_2022_high['검정고시 및 교육과정 이수자-합계'] = df_2022_high['검정고시 및 교육과정 이수자-합계'].fillna(2)

df_2023_high['당해연도 졸업자-합계'] = df_2023_high['당해연도 졸업자-합계'].fillna(207)
df_2023_high['이전연도 졸업자-합계'] = df_2023_high['이전연도 졸업자-합계'].fillna(1)
df_2023_high['검정고시 및 교육과정 이수자-합계'] = df_2023_high['검정고시 및 교육과정 이수자-합계'].fillna(2)

df_2024_high['당해연도 졸업자-합계'] = df_2024_high['당해연도 졸업자-합계'].fillna(207)
df_2024_high['이전연도 졸업자-합계'] = df_2024_high['이전연도 졸업자-합계'].fillna(1)
df_2024_high['검정고시 및 교육과정 이수자-합계'] = df_2024_high['검정고시 및 교육과정 이수자-합계'].fillna(2)
# Out:
# C:\Users\brian\AppData\Local\Temp\ipykernel_20156\2083469192.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_middle['당해연도 졸업자-합계'] = df_2022_middle['당해연도 졸업자-합계'].fillna(207)
# C:\Users\brian\AppData\Local\Temp\ipykernel_20156\2083469192.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022_middle['이전연도 졸업자-합계'] = df_2022_middle['이전연도 졸업자-합계'].fillna(1)
# C:\Users\brian\AppData\Local\Temp\ipykernel_20156\2083469192.py:61: SettingWithCopyWarning:
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'Malgun Gothic'

#초등학교 통계량 - 적령 아동-합계
 #2021

df_2021_ele_fit = (df_2021_ele
               .groupby(['지역'])['적령 아동-합계']
               .sum())


df_2021_ele_fit.plot(kind ='bar' , x = '지역', y = '적령 아동-합계'
             , figsize = (10,6) , color = 'skyblue')

plt.title('2021지역별 적령 아동수')
plt.xlabel('지역')
plt.ylabel('2021적령아동수')
# Out:
# Text(0, 0.5, '2021적령아동수')

# %%
#초등학교 통계량 - 적령 아동-합계
 #2022
df_2022_ele_fit = (df_2022_ele
               .groupby(['지역'])['적령 아동-합계']
               .sum())

df_2022_ele_fit.plot(kind ='bar' , x = '지역', y = '적령 아동-합계'
             , figsize = (10,6) , color = 'skyblue')

plt.title('2022지역별 적령 아동수')
plt.xlabel('지역')
plt.ylabel('2022적령아동수')
# Out:
# Text(0, 0.5, '2022적령아동수')

# %%
#초등학교 통계량 - 적령 아동-합계
 #2023
df_2023_ele_fit = (concat_2023_ele
               .groupby(['지역'])['적령 아동-합계']
               .sum())

df_2023_ele_fit.plot(kind ='bar' , x = '지역', y = '적령 아동-합계'
             , figsize = (10,6) , color = 'skyblue')

plt.title('2023지역별 적령 아동수')
plt.xlabel('지역')
plt.ylabel('2023적령아동수')
# Out:
# Text(0, 0.5, '2023적령아동수')

# %%
#초등학교 통계량 - 적령 아동-합계
 #2024
df_2024_ele_fit = (concat_2024_ele
               .groupby(['지역'])['적령 아동-합계']
               .sum())

df_2024_ele_fit.plot(kind ='bar' , x = '지역', y = '적령 아동-합계'
             , figsize = (10,6) , color = 'skyblue')

plt.title('2024지역별 적령 아동수')
plt.xlabel('지역')
plt.ylabel('2024적령아동수')
# Out:
# Text(0, 0.5, '2024적령아동수')

# %%
#초등학교 통계량 - 유예 및 과령 아동-합계
 #2021
 #유예 및 과령 아동-합계
df_2021_elem_over = (df_2021_ele
                    .groupby(['지역'])['유예 및 과령 아동-합계']
                    .sum())

df_2021_elem_over.plot(kind ='bar' , x = '지역', y = '유예 및 과령 아동-합계'
             , figsize = (10,6) , color = 'pink')

plt.title('2021유예 및 과령 아동-합계')
plt.xlabel('지역')
plt.ylabel('2021유예 및 과령 아동-합계')
# Out:
# Text(0, 0.5, '2021유예 및 과령 아동-합계')

# %%
#초등학교 통계량 - 유예 및 과령 아동-합계
 #2022
 #유예 및 과령 아동-합계
df_2022_elem_over = (df_2022_ele
                    .groupby(['지역'])['유예 및 과령 아동-합계']
                    .sum())

df_2022_elem_over.plot(kind ='bar' , x = '지역', y = '유예 및 과령 아동-합계'
             , figsize = (10,6) , color = 'pink')

plt.title('2022유예 및 과령 아동-합계')
plt.xlabel('지역')
plt.ylabel('2022유예 및 과령 아동-합계')
# Out:
# Text(0, 0.5, '2022유예 및 과령 아동-합계')

# %%
#초등학교 통계량 - 유예 및 과령 아동-합계
 #2023
 #유예 및 과령 아동-합계
df_2023_elem_over = (concat_2023_ele
                    .groupby(['지역'])['유예 및 과령 아동-합계']
                    .sum())

df_2023_elem_over.plot(kind ='bar' , x = '지역', y = '유예 및 과령 아동-합계'
             , figsize = (10,6) , color = 'pink')

plt.title('2023유예 및 과령 아동-합계')
plt.xlabel('지역')
plt.ylabel('2023유예 및 과령 아동-합계')
# Out:
# Text(0, 0.5, '2023유예 및 과령 아동-합계')

# %%
#초등학교 통계량 - 유예 및 과령 아동-합계
 #2024
 #유예 및 과령 아동-합계
df_2024_elem_over = (concat_2024_ele
                    .groupby(['지역'])['유예 및 과령 아동-합계']
                    .sum())

df_2024_elem_over.plot(kind ='bar' , x = '지역', y = '유예 및 과령 아동-합계'
             , figsize = (10,6) , color = 'pink')

plt.title('2024유예 및 과령 아동-합계')
plt.xlabel('지역')
plt.ylabel('2024유예 및 과령 아동-합계')
# Out:
# Text(0, 0.5, '2024유예 및 과령 아동-합계')

# %%
#초등학교 통계량 - 조기입학아동-합계
 #2021
 #조기입학아동-합계
df_2021_elem_ear = (df_2021_ele
                    .groupby(['지역'])['조기입학아동-합계']
                    .sum())

df_2021_elem_ear.plot(kind ='bar' , x = '지역', y = '조기입학아동-합계'
             , figsize = (10,6) , color = 'gray')

plt.title('2021조기입학아동-합계')
plt.xlabel('지역')
plt.ylabel('2021조기입학아동-합계')
# Out:
# Text(0, 0.5, '2021조기입학아동-합계')

# %%
#초등학교 통계량 - 조기입학아동-합계
 #2022
 #조기입학아동-합계
df_2022_elem_ear = (df_2022_ele
                    .groupby(['지역'])['조기입학아동-합계']
                    .sum())

df_2022_elem_ear.plot(kind ='bar' , x = '지역', y = '조기입학아동-합계'
             , figsize = (10,6) , color = 'gray')

plt.title('2022조기입학아동-합계')
plt.xlabel('지역')
plt.ylabel('2022조기입학아동-합계')
# Out:
# Text(0, 0.5, '2022조기입학아동-합계')

# %%
#초등학교 통계량 - 조기입학아동-합계
 #2023
 #조기입학아동-합계
df_2023_elem_ear = (concat_2023_ele
                    .groupby(['지역'])['조기입학아동-합계']
                    .sum())

df_2023_elem_ear.plot(kind ='bar' , x = '지역', y = '조기입학아동-합계'
             , figsize = (10,6) , color = 'gray')

plt.title('2023조기입학아동-합계')
plt.xlabel('지역')
plt.ylabel('2023조기입학아동-합계')
# Out:
# Text(0, 0.5, '2023조기입학아동-합계')

# %%
#초등학교 통계량 - 조기입학아동-합계
 #2023
 #조기입학아동-합계
df_2024_elem_ear = (concat_2024_ele
                    .groupby(['지역'])['조기입학아동-합계']
                    .sum())

df_2024_elem_ear.plot(kind ='bar' , x = '지역', y = '조기입학아동-합계'
             , figsize = (10,6) , color = 'gray')

plt.title('2024조기입학아동-합계')
plt.xlabel('지역')
plt.ylabel('2024조기입학아동-합계')
# Out:
# Text(0, 0.5, '2024조기입학아동-합계')
